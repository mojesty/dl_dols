# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 40000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 523133], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'anarchism', 'originated', 'a', 'term', 'originated', 'of', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 80001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.037565
# Nearest to years: aberdeenshire, imaginations, divide, fists, vicki, tenses, willow, halas,
# Nearest to three: unsupported, atsc, adjusts, unmistakable, cry, transmigration, likewise, mountains,
# Nearest to was: chuck, vanderbilt, dickinson, luca, exchequer, mit, leftists, albany,
# Nearest to state: intuitively, imdb, limp, athens, cryptology, genscher, indiana, azerbaijani,
# Nearest to he: keeshond, samhain, delle, interprets, oldsmobile, magneto, capitalization, kits,
# Nearest to were: peregrine, sarah, suharto, restoration, baker, wadsworth, kiki, jinx,
# Nearest to some: burning, scat, carnot, chuppah, muslim, doodle, hymnal, tolls,
# Nearest to d: highest, boldly, corte, veracruz, differentiating, hypotheses, pertain, generalizations,
# Nearest to often: nationals, protecting, melton, pausanias, sociology, separating, dealt, petition,
# Nearest to one: foliage, winters, nascar, patton, derive, paternal, infringe, asatru,
# Nearest to all: conveys, turnpike, taiwanese, equalled, orphan, attaches, delian, arm,
# Nearest to other: countries, geologist, wheeled, nance, uda, mnt, mitochondria, snowmobile,
# Nearest to s: hermetic, fi, linden, hospitality, nakajima, murky, obligate, bouldering,
# Nearest to it: christy, khoisan, mail, pharaoh, boas, undivided, predetermined, procedure,
# Nearest to and: duration, fricative, dorsal, hover, monte, structural, twins, here,
# Nearest to by: juris, exact, felonies, hyman, honour, collier, quartz, tomcat,
# Average loss at step 2000: 4.300954
# Average loss at step 4000: 3.821035
# Average loss at step 6000: 3.756979
# Average loss at step 8000: 3.661320
# Average loss at step 10000: 3.592632
# Nearest to years: imaginations, heidelberg, ey, halas, willow, bloodlines, brundtland, fists,
# Nearest to three: four, six, five, eight, seven, nine, two, zero,
# Nearest to was: is, has, by, had, were, been, be, volcanoes,
# Nearest to state: limp, donation, intuitively, athens, imdb, set, beneath, settlements,
# Nearest to he: it, she, they, who, aikido, interprets, which, that,
# Nearest to were: are, was, have, had, goth, sarah, be, cpus,
# Nearest to some: carnot, many, tolls, amicable, ginette, comfortably, burning, lds,
# Nearest to d: b, veracruz, highest, boldly, premiered, timbre, differentiating, generalizations,
# Nearest to often: no, also, still, astronomy, dealt, staged, rudder, petition,
# Nearest to one: two, three, seven, four, pp, eight, fayed, six,
# Nearest to all: burning, turnpike, brain, external, semantically, plato, evaluation, elektra,
# Nearest to other: countries, mnt, many, unbalanced, po, marriages, jaynes, these,
# Nearest to s: his, opus, federations, and, withstand, shattering, hospitality, kaspar,
# Nearest to it: he, this, there, she, which, they, also, that,
# Nearest to and: or, freya, in, nineteen, of, reflexive, tsang, recommendation,
# Nearest to by: was, dickinson, into, from, as, assessments, with, inorganic,
# Average loss at step 12000: 3.589482
# Average loss at step 14000: 3.554255
# Average loss at step 16000: 3.387982
# Average loss at step 18000: 3.443906
# Average loss at step 20000: 3.527389
# Nearest to years: imaginations, months, brundtland, heidelberg, pushed, benoit, ey, willow,
# Nearest to three: four, seven, six, five, two, eight, zero, nine,
# Nearest to was: is, has, were, had, became, be, efficiencies, when,
# Nearest to state: intuitively, limp, donation, set, athens, credible, imdb, enabling,
# Nearest to he: it, she, they, who, there, keeshond, which, canova,
# Nearest to were: are, was, have, had, occam, be, by, goth,
# Nearest to some: many, these, several, their, harshly, all, other, those,
# Nearest to d: b, veracruz, french, eight, generalizations, tapioca, innovator, kemp,
# Nearest to often: also, usually, still, sometimes, frequently, dealt, no, diatomic,
# Nearest to one: two, three, four, seven, six, eight, nine, pp,
# Nearest to all: many, those, some, grinding, external, sweetener, syria, course,
# Nearest to other: many, these, countries, some, different, unbalanced, qe, bacchus,
# Nearest to s: pok, whose, dunn, shattering, cologne, protoscience, multithreading, nigeria,
# Nearest to it: he, this, there, she, they, which, not, we,
# Nearest to and: or, which, mountain, but, in, at, inescapable, zionist,
# Nearest to by: for, be, were, from, is, dickinson, into, was,
# Average loss at step 22000: 3.494001
# Average loss at step 24000: 3.477218
# Average loss at step 26000: 3.468733
# Average loss at step 28000: 3.465888
# Average loss at step 30000: 3.491851
# Nearest to years: months, imaginations, ey, danforth, brundtland, benoit, litre, times,
# Nearest to three: four, five, seven, six, two, eight, nine, zero,
# Nearest to was: is, were, has, had, became, been, be, endosymbionts,
# Nearest to state: donation, intuitively, limp, states, athens, tradition, credible, merritt,
# Nearest to he: she, it, they, who, there, ais, keeshond, never,
# Nearest to were: are, was, had, have, mitre, clampett, occam, been,
# Nearest to some: many, these, several, those, most, their, all, other,
# Nearest to d: b, generalizations, pouring, kemp, veracruz, allison, permian, tapioca,
# Nearest to often: sometimes, usually, also, frequently, still, widely, now, not,
# Nearest to one: two, seven, four, six, three, eight, five, nine,
# Nearest to all: some, many, vdash, any, those, grinding, brain, sweetener,
# Nearest to other: these, different, some, many, unbalanced, various, aw, such,
# Nearest to s: his, whose, endosymbionts, burke, putty, nipple, describing, grant,
# Nearest to it: he, there, this, she, they, not, which, also,
# Nearest to and: or, but, in, mountain, who, yankees, like, of,
# Nearest to by: with, under, during, were, from, in, was, refrigerator,
# Average loss at step 32000: 3.488967
# Average loss at step 34000: 3.485702
# Average loss at step 36000: 3.443162
# Average loss at step 38000: 3.293994
# Average loss at step 40000: 3.422096
# Nearest to years: months, days, times, stocking, wasps, imaginations, danforth, time,
# Nearest to three: five, four, two, six, seven, eight, nine, zero,
# Nearest to was: is, had, has, were, became, been, be, when,
# Nearest to state: intuitively, states, donation, lensman, tradition, limp, shake, merritt,
# Nearest to he: she, it, they, who, there, i, then, never,
# Nearest to were: are, have, was, had, occam, been, mitre, hamel,
# Nearest to some: many, these, several, any, certain, both, those, such,
# Nearest to d: b, r, UNK, kemp, generalizations, hypotheses, moravian, veracruz,
# Nearest to often: sometimes, usually, also, frequently, still, widely, generally, commonly,
# Nearest to one: seven, four, eight, six, two, five, three, nine,
# Nearest to all: both, several, vdash, any, three, every, converged, sweetener,
# Nearest to other: different, various, including, many, unbalanced, such, aw, sec,
# Nearest to s: putty, his, freire, dunn, ord, shattering, lorraine, superstring,
# Nearest to it: he, there, she, this, they, which, still, not,
# Nearest to and: or, but, in, proudly, including, signalling, ectopic, carmen,
# Nearest to by: with, dickinson, certify, from, be, as, fills, when,
# Average loss at step 42000: 3.434489
# Average loss at step 44000: 3.445176
# Average loss at step 46000: 3.444029
# Average loss at step 48000: 3.350026
# Average loss at step 50000: 3.379640
# Nearest to years: months, days, times, people, year, imaginations, wikiproject, time,
# Nearest to three: six, four, seven, five, two, eight, nine, zero,
# Nearest to was: is, were, has, became, had, be, by, been,
# Nearest to state: intuitively, lensman, donation, states, limp, astatine, loo, slanted,
# Nearest to he: she, it, they, who, there, eventually, we, this,
# Nearest to were: are, was, have, occam, be, had, been, mitre,
# Nearest to some: many, these, several, both, the, those, slobodan, any,
# Nearest to d: b, r, generalizations, m, moravian, kemp, hypotheses, barton,
# Nearest to often: sometimes, usually, generally, frequently, widely, now, also, commonly,
# Nearest to one: two, six, seven, eight, four, three, five, nine,
# Nearest to all: every, both, bullseye, any, sweetener, each, hutton, these,
# Nearest to other: different, various, many, aw, these, some, sock, heinemann,
# Nearest to s: whose, putty, hospitality, his, shattering, websites, landforms, cycles,
# Nearest to it: he, there, she, this, they, actually, now, not,
# Nearest to and: or, but, experimenter, of, including, perched, proc, kal,
# Nearest to by: was, under, emile, through, troupes, hyman, be, dickinson,
# Average loss at step 52000: 3.435414
# Average loss at step 54000: 3.416134
# Average loss at step 56000: 3.438152
# Average loss at step 58000: 3.389611
# Average loss at step 60000: 3.394995
# Nearest to years: months, days, times, year, imaginations, gallons, decades, centuries,
# Nearest to three: five, four, six, eight, seven, two, nine, zero,
# Nearest to was: is, had, were, became, has, been, seems, although,
# Nearest to state: intuitively, loo, settlements, government, slanted, beneath, astatine, aclu,
# Nearest to he: she, it, they, who, there, we, keeshond, soon,
# Nearest to were: are, was, have, had, occam, those, including, been,
# Nearest to some: many, several, these, certain, any, both, most, the,
# Nearest to d: b, r, generalizations, m, hypotheses, moravian, concomitant, f,
# Nearest to often: sometimes, usually, frequently, generally, now, commonly, also, widely,
# Nearest to one: two, seven, eight, four, six, nine, five, three,
# Nearest to all: any, both, those, every, these, many, some, bullseye,
# Nearest to other: different, various, many, longer, including, plutinos, those, are,
# Nearest to s: whose, shattering, hospitality, burke, tinymud, your, cycles, occult,
# Nearest to it: he, there, she, this, which, what, that, they,
# Nearest to and: or, but, acton, targeted, in, genetically, ectopic, experimenter,
# Nearest to by: through, with, assessments, fills, using, redaction, rearranged, fachhochschule,
# Average loss at step 62000: 3.235636
# Average loss at step 64000: 3.248157
# Average loss at step 66000: 3.399031
# Average loss at step 68000: 3.390837
# Average loss at step 70000: 3.360363
# Nearest to years: months, days, year, times, decades, surpass, centuries, percent,
# Nearest to three: four, five, six, two, seven, eight, nine, zero,
# Nearest to was: is, were, had, has, became, be, been, when,
# Nearest to state: lensman, government, intuitively, astatine, states, slanted, palace, loo,
# Nearest to he: she, it, they, there, who, we, eventually, mitzvot,
# Nearest to were: are, have, was, be, had, been, include, including,
# Nearest to some: many, these, several, both, certain, all, those, any,
# Nearest to d: b, r, generalizations, hypotheses, m, moravian, ralph, palatine,
# Nearest to often: sometimes, usually, frequently, generally, now, commonly, still, also,
# Nearest to one: two, seven, six, four, eight, five, nine, three,
# Nearest to all: any, both, many, some, every, bullseye, various, those,
# Nearest to other: different, various, many, including, stupid, some, such, longer,
# Nearest to s: whose, hospitality, your, isbn, feels, revising, dunn, putty,
# Nearest to it: he, there, she, this, they, still, actually, we,
# Nearest to and: or, but, while, like, which, including, tsang, hirsch,
# Nearest to by: through, be, using, certify, in, dickinson, rearranged, chaplin,
# Average loss at step 72000: 3.368528
# Average loss at step 74000: 3.348235
# Average loss at step 76000: 3.302871
# Average loss at step 78000: 3.345599
# Average loss at step 80000: 3.369069
# Nearest to years: months, days, year, times, decades, minutes, centuries, percent,
# Nearest to three: six, four, seven, five, two, eight, nine, zero,
# Nearest to was: is, became, were, has, had, seems, becomes, jeffreys,
# Nearest to state: lensman, states, slanted, government, palace, astatine, bog, tune,
# Nearest to he: she, it, they, there, who, we, eventually, leto,
# Nearest to were: are, have, had, was, been, those, be, include,
# Nearest to some: many, several, these, both, any, certain, most, various,
# Nearest to d: b, m, generalizations, r, hypotheses, fw, moravian, khyber,
# Nearest to often: sometimes, usually, generally, commonly, frequently, now, still, also,
# Nearest to one: seven, two, six, three, eight, four, five, nine,
# Nearest to all: both, any, many, every, bullseye, various, some, several,
# Nearest to other: various, different, others, many, aw, those, plutinos, including,
# Nearest to s: freire, putty, isbn, specifications, protoscience, hospitality, hospitalized, kemerovo,
# Nearest to it: he, she, there, this, they, we, actually, itself,
# Nearest to and: or, but, targeted, kal, acton, who, bateson, xxxviii,
# Nearest to by: through, troupes, sir, hyman, using, chaplin, uttar, fee,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
num_steps = 80001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        # WOW SUCH CBOW
        batch_labels, batch_data = generate_batch(batch_size, num_skips, skip_window)

        batch_labels = batch_labels.reshape((batch_size, 1))
        batch_data = batch_data.reshape((batch_size,))
        
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From <ipython-input-13-1451dbdf71b9>:4: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step 0: 8.405917
# Nearest to years: protective, hilbert, inquirer, coronation, rem, activated, sportscaster, alegre,
# Nearest to three: musical, infighting, wettest, lutz, albeit, salish, dressage, harbours,
# Nearest to was: intelligentsia, hellespont, prosperity, evening, cays, mjf, boson, mascots,
# Nearest to state: hz, fertilized, normal, dixieland, eurasian, keynes, inducted, serpents,
# Nearest to he: fruits, manipulations, abdallah, clocks, dunbar, busey, pheromones, designates,
# Nearest to were: plaintiffs, gamma, transliteration, mgm, dramas, manipulative, cheddar, lice,
# Nearest to some: katherine, omits, petrovich, bavaria, pacioli, gaul, underwear, bakelite,
# Nearest to d: preeminent, fishing, lighthouses, columns, suffice, digit, schultz, eng,
# Nearest to often: permissible, darwin, vita, conditional, rowan, raleigh, burma, dandy,
# Nearest to one: addicted, handsome, ax, chroniclers, reform, jh, flashbacks, intervocalic,
# Nearest to all: yam, fock, approximants, bony, honeybee, driscoll, bac, pharaohs,
# Nearest to other: vardar, protagonists, consultants, retains, exercised, precepts, statistic, motherland,
# Nearest to s: oberlin, zone, wane, principalities, hydroponic, solo, lamanites, vizier,
# Nearest to it: mis, literatures, drowning, olympian, thriving, kenny, harrington, ceiling,
# Nearest to and: beet, afoul, impotence, realities, mclaren, uppsala, summoning, vliw,
# Nearest to by: communists, ap, johann, here, collided, beginners, correctly, olives,
# Average loss at step 2000: 4.350053
# Average loss at step 4000: 3.916344
# Average loss at step 6000: 3.797612
# Average loss at step 8000: 3.693345
# Average loss at step 10000: 3.647076
# Nearest to years: protective, coronation, rem, activated, hilbert, inquirer, gold, dummies,
# Nearest to three: four, five, two, seven, eight, six, zero, one,
# Nearest to was: is, had, were, has, be, by, became, plugged,
# Nearest to state: baggage, hz, eurasian, keynes, brick, normal, confession, swf,
# Nearest to he: it, who, they, she, inspections, there, shaving, ounces,
# Nearest to were: are, was, have, had, superintendent, js, has, by,
# Nearest to some: many, these, omits, tlc, caen, covertly, rhinoceros, uni,
# Nearest to d: diploid, counsel, versus, reproach, aqueous, hamlet, manor, fishing,
# Nearest to often: aegis, vita, also, which, darwin, conditional, strived, beavis,
# Nearest to one: four, two, six, seven, three, eight, five, nine,
# Nearest to all: yam, death, smoking, penalized, epistolary, negligence, danville, searched,
# Nearest to other: cards, charlemagne, precepts, games, new, odegard, accessibility, super,
# Nearest to s: contribution, invulnerable, pascha, solo, designating, his, dismissing, rd,
# Nearest to it: he, this, they, there, which, recognised, not, she,
# Nearest to and: or, in, neutral, by, of, pressing, but, laurel,
# Nearest to by: was, aluminium, and, tantric, under, from, beginners, as,
# Average loss at step 12000: 3.667565
# Average loss at step 14000: 3.548296
# Average loss at step 16000: 3.598597
# Average loss at step 18000: 3.456450
# Average loss at step 20000: 3.565559
# Nearest to years: protective, days, coronation, categories, dummies, belarusians, rem, pigeon,
# Nearest to three: four, five, six, two, seven, eight, zero, nine,
# Nearest to was: is, has, were, became, had, s, been, plugged,
# Nearest to state: baggage, us, eurasian, technical, alpha, brick, photons, keynes,
# Nearest to he: it, she, they, who, there, inspections, bundeswehr, sidereal,
# Nearest to were: are, was, have, by, had, is, hurts, boulogne,
# Nearest to some: many, these, the, all, most, omits, caen, any,
# Nearest to d: b, counsel, c, atoll, diploid, charles, burbank, takeover,
# Nearest to often: usually, sometimes, generally, commonly, aegis, also, now, not,
# Nearest to one: two, four, seven, eight, six, five, nine, three,
# Nearest to all: some, yam, cymbals, these, death, them, penalized, tcl,
# Nearest to other: many, franconian, nutrition, accessibility, containing, grille, mande, precepts,
# Nearest to s: invulnerable, his, was, and, solo, genuinely, rogues, the,
# Nearest to it: he, this, there, she, not, they, which, recognised,
# Nearest to and: or, when, but, of, s, who, austen, thatcher,
# Nearest to by: be, were, through, when, under, cabbage, from, was,
# Average loss at step 22000: 3.521908
# Average loss at step 24000: 3.487691
# Average loss at step 26000: 3.515533
# Average loss at step 28000: 3.512121
# Average loss at step 30000: 3.421849
# Nearest to years: days, protective, categories, coronation, dummies, year, belarusians, laptops,
# Nearest to three: five, four, six, seven, two, eight, one, zero,
# Nearest to was: is, has, were, had, became, by, be, been,
# Nearest to state: baggage, us, amount, technical, brick, nissan, confession, optional,
# Nearest to he: she, it, they, who, there, later, eventually, ergative,
# Nearest to were: are, was, have, had, is, baltasar, being, intercept,
# Nearest to some: many, these, all, this, several, most, other, any,
# Nearest to d: b, c, diploid, counsel, l, o, captained, burbank,
# Nearest to often: usually, sometimes, generally, commonly, widely, also, now, typically,
# Nearest to one: two, seven, three, five, six, eight, four, nine,
# Nearest to all: some, many, these, cymbals, peacetime, any, adjectives, certain,
# Nearest to other: franconian, some, including, different, mande, containing, those, many,
# Nearest to s: invulnerable, sami, the, tetra, steeply, parameter, beaumont, manslaughter,
# Nearest to it: he, there, she, this, which, they, but, moderne,
# Nearest to and: or, in, but, for, of, with, including, from,
# Nearest to by: was, against, when, with, through, under, in, beginners,
# Average loss at step 32000: 3.421518
# Average loss at step 34000: 3.460340
# Average loss at step 36000: 3.452539
# Average loss at step 38000: 3.457949
# Average loss at step 40000: 3.446117
# Nearest to years: days, months, protective, year, times, past, dummies, categories,
# Nearest to three: four, five, six, two, seven, eight, nine, one,
# Nearest to was: is, had, has, were, became, by, been, be,
# Nearest to state: amount, us, baggage, technical, galicia, brick, use, nissan,
# Nearest to he: she, it, they, there, who, eventually, but, seminars,
# Nearest to were: are, was, have, had, hurts, be, those, became,
# Nearest to some: many, all, several, these, most, any, their, other,
# Nearest to d: b, c, e, o, l, j, diploid, counsel,
# Nearest to often: usually, sometimes, generally, commonly, widely, also, typically, now,
# Nearest to one: seven, two, three, four, six, nine, five, eight,
# Nearest to all: some, many, these, cymbals, any, each, depravity, several,
# Nearest to other: including, different, some, franconian, somoza, those, ruled, many,
# Nearest to s: his, invulnerable, solo, rpm, dismissing, and, whirlpool, rapture,
# Nearest to it: he, there, she, this, they, which, but, we,
# Nearest to and: or, but, however, including, s, of, breve, who,
# Nearest to by: was, through, be, from, under, as, been, during,
# Average loss at step 42000: 3.434444
# Average loss at step 44000: 3.351613
# Average loss at step 46000: 3.331998
# Average loss at step 48000: 3.399937
# Average loss at step 50000: 3.327005
# Nearest to years: days, months, protective, year, times, past, hours, minutes,
# Nearest to three: four, six, seven, five, two, eight, nine, zero,
# Nearest to was: is, had, became, has, were, be, historicity, gets,
# Nearest to state: amount, galicia, technical, baggage, iga, permanently, us, bird,
# Nearest to he: she, it, they, there, who, never, later, soon,
# Nearest to were: are, was, have, had, be, hurts, include, those,
# Nearest to some: many, these, several, all, both, most, any, certain,
# Nearest to d: b, thomas, lugh, yah, sympathetic, burbank, pinning, bb,
# Nearest to often: sometimes, usually, generally, commonly, also, widely, typically, now,
# Nearest to one: seven, four, six, two, five, counsellor, traffickers, mathematics,
# Nearest to all: some, many, both, these, each, any, every, out,
# Nearest to other: different, precepts, rotational, grille, franconian, diploid, various, lcm,
# Nearest to s: invulnerable, tetra, quotations, hazael, his, respectively, miniaturized, pascha,
# Nearest to it: he, there, she, this, they, often, which, we,
# Nearest to and: but, or, who, when, including, which, ajmer, where,
# Nearest to by: with, dearborn, through, cabbage, beginners, tantric, under, shenzhen,
# Average loss at step 52000: 3.349163
# Average loss at step 54000: 3.378193
# Average loss at step 56000: 3.284630
# Average loss at step 58000: 3.425945
# Average loss at step 60000: 3.390581
# Nearest to years: days, months, year, times, minutes, past, protective, decades,
# Nearest to three: five, four, six, two, seven, eight, zero, nine,
# Nearest to was: is, has, were, became, had, be, been, when,
# Nearest to state: government, amount, galicia, states, baggage, iga, bird, disrupts,
# Nearest to he: she, it, they, there, who, eventually, later, soon,
# Nearest to were: are, was, have, had, been, be, hurts, those,
# Nearest to some: many, these, several, both, all, most, any, the,
# Nearest to d: b, c, lugh, l, cos, counsel, burbank, p,
# Nearest to often: sometimes, usually, commonly, generally, widely, also, typically, frequently,
# Nearest to one: two, seven, six, four, five, eight, three, dreaming,
# Nearest to all: both, some, many, these, every, certain, any, circulating,
# Nearest to other: many, various, different, lcm, rotational, precepts, including, those,
# Nearest to s: invulnerable, narbonne, quotations, rogues, dismissing, his, duplicated, tetra,
# Nearest to it: he, she, there, they, this, we, which, itself,
# Nearest to and: or, but, leibniz, ajmer, although, circuses, however, paddington,
# Nearest to by: without, for, through, been, wikisource, using, shenzhen, beginners,
# Average loss at step 62000: 3.373038
# Average loss at step 64000: 3.226563
# Average loss at step 66000: 3.368089
# Average loss at step 68000: 3.385626
# Average loss at step 70000: 3.386762
# Nearest to years: days, months, year, times, minutes, decades, hours, past,
# Nearest to three: four, five, six, seven, two, eight, nine, zero,
# Nearest to was: is, had, has, became, were, when, historicity, be,
# Nearest to state: government, states, galicia, disrupts, office, amount, labor, iga,
# Nearest to he: she, it, they, there, who, we, eventually, knoxville,
# Nearest to were: are, have, was, those, had, be, although, these,
# Nearest to some: many, several, these, any, certain, most, all, their,
# Nearest to d: b, c, l, j, counsel, aqueous, n, k,
# Nearest to often: usually, sometimes, typically, generally, commonly, also, now, widely,
# Nearest to one: seven, two, five, four, six, three, eight, haw,
# Nearest to all: both, many, every, some, several, each, certain, any,
# Nearest to other: including, many, different, lcm, various, consummated, others, several,
# Nearest to s: rogues, whose, oddie, cantata, duplicated, rpm, dismissing, ingesting,
# Nearest to it: he, she, there, this, they, we, which, drifting,
# Nearest to and: or, but, however, while, including, although, resigns, ojibwe,
# Nearest to by: haymarket, when, sotho, noel, with, cabbage, against, under,
# Average loss at step 72000: 3.410051
# Average loss at step 74000: 3.392679
# Average loss at step 76000: 3.364891
# Average loss at step 78000: 3.243035
# Average loss at step 80000: 3.348043
# Nearest to years: days, months, year, decades, minutes, times, hours, past,
# Nearest to three: four, five, six, seven, eight, two, nine, one,
# Nearest to was: is, became, were, had, has, when, been, be,
# Nearest to state: government, states, galicia, view, brick, bird, labor, office,
# Nearest to he: she, it, they, there, who, eventually, soon, we,
# Nearest to were: are, was, those, have, had, including, being, include,
# Nearest to some: many, several, these, all, those, any, certain, both,
# Nearest to d: b, l, c, n, j, counsel, o, k,
# Nearest to often: usually, sometimes, generally, commonly, typically, frequently, also, now,
# Nearest to one: two, four, three, six, eight, five, seven, booker,
# Nearest to all: many, both, some, several, various, any, these, certain,
# Nearest to other: including, various, different, franconian, consummated, many, several, mitigating,
# Nearest to s: whose, dismissing, invulnerable, rpm, ais, rogues, duplicated, ingesting,
# Nearest to it: he, she, there, they, this, we, which, itself,
# Nearest to and: or, but, including, mortis, while, although, however, royce,
# Nearest to by: against, tantric, was, sotho, without, haymarket, in, when,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
